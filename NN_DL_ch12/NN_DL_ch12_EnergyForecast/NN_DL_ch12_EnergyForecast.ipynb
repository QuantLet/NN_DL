# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/QuantLet/NN_DL/blob/main/NN_DL_ch12/NN_DL_ch12_EnergyForecast/NN_DL_ch12_EnergyForecast.ipynb)
#
# # NN_DL_ch12_EnergyForecast
#
# **Description:** LSTM/Transformer for Romanian energy price forecasting
#
# **Keywords:** energy finance, price forecasting, LSTM, Romanian market, AI4EFin
#
# **Author:** Daniel Traian Pele, ASE Bucharest / IDA

# %%
# !pip install torch torchvision matplotlib numpy scikit-learn -q

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
np.random.seed(42); torch.manual_seed(42)
MAIN_BLUE='#1A3A6E'; IDA_RED='#CD0000'; FOREST='#2E7D32'; CRIMSON='#DC3545'
print('Ready: NN_DL_ch12_EnergyForecast')

# %% [markdown]
# ## Data

# %%
# TODO: Load energy price data

# %% [markdown]
# ## Model

# %%
# TODO: LSTM for forecasting

# %% [markdown]
# ## Results

# %%
# TODO: Evaluate and visualize
