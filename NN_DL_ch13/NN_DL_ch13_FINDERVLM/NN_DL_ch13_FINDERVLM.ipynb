# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/QuantLet/NN_DL/blob/main/NN_DL_ch13/NN_DL_ch13_FINDERVLM/NN_DL_ch13_FINDERVLM.ipynb)
#
# # NN_DL_ch13_FINDERVLM
#
# **Description:** FINDER-VLM: multimodal crash prediction combining charts and text
#
# **Keywords:** FINDER-VLM, multimodal, vision-language model, crash prediction
#
# **Author:** Daniel Traian Pele, ASE Bucharest / IDA

# %%
# !pip install torch torchvision matplotlib numpy scikit-learn -q

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
np.random.seed(42); torch.manual_seed(42)
MAIN_BLUE='#1A3A6E'; IDA_RED='#CD0000'; FOREST='#2E7D32'; CRIMSON='#DC3545'
print('Ready: NN_DL_ch13_FINDERVLM')

# %% [markdown]
# ## Data

# %%
# TODO: Chart image + text data

# %% [markdown]
# ## Model

# %%
# TODO: Multimodal architecture

# %% [markdown]
# ## Results

# %%
# TODO: Train and evaluate
