# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/QuantLet/NN_DL/blob/main/NN_DL_ch09/NN_DL_ch09_Portfolio/NN_DL_ch09_Portfolio.ipynb)
#
# # NN_DL_ch09_Portfolio
#
# **Description:** Deep RL agent for multi-asset portfolio optimization
#
# **Keywords:** reinforcement learning, portfolio optimization, PPO, DQN, finance
#
# **Author:** Daniel Traian Pele, ASE Bucharest / IDA

# %%
# !pip install torch torchvision matplotlib numpy scikit-learn -q

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
np.random.seed(42); torch.manual_seed(42)
MAIN_BLUE='#1A3A6E'; IDA_RED='#CD0000'; FOREST='#2E7D32'; CRIMSON='#DC3545'
print('Ready: NN_DL_ch09_Portfolio')

# %% [markdown]
# ## Environment

# %%
# TODO: Define trading environment

# %% [markdown]
# ## Agent

# %%
# TODO: PPO/DQN agent

# %% [markdown]
# ## Training

# %%
# TODO: Train and evaluate
