# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/QuantLet/NN_DL/blob/main/NN_DL_ch11/NN_DL_ch11_PromptEngineering/NN_DL_ch11_PromptEngineering.ipynb)
#
# # NN_DL_ch11_PromptEngineering
#
# **Description:** Prompt engineering patterns for financial analysis with LLMs
#
# **Keywords:** prompt engineering, LLM, financial analysis, zero-shot, few-shot, chain-of-thought
#
# **Author:** Daniel Traian Pele, ASE Bucharest / IDA

# %%
# !pip install torch torchvision matplotlib numpy scikit-learn -q

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
np.random.seed(42); torch.manual_seed(42)
MAIN_BLUE='#1A3A6E'; IDA_RED='#CD0000'; FOREST='#2E7D32'; CRIMSON='#DC3545'
print('Ready: NN_DL_ch11_PromptEngineering')

# %% [markdown]
# ## Setup

# %%
# TODO: OpenAI/Anthropic API setup

# %% [markdown]
# ## Prompts

# %%
# TODO: Structured prompt templates

# %% [markdown]
# ## Backtesting

# %%
# TODO: VaR backtesting pipeline
