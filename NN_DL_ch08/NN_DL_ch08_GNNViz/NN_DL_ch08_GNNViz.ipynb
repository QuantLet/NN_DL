# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/QuantLet/NN_DL/blob/main/NN_DL_ch08/NN_DL_ch08_GNNViz/NN_DL_ch08_GNNViz.ipynb)
#
# # NN_DL_ch08_GNNViz
#
# **Description:** Visualize message passing, GCN/GAT, and graph embeddings
#
# **Keywords:** GNN, GCN, GAT, message passing, graph visualization
#
# **Author:** Daniel Traian Pele, ASE Bucharest / IDA

# %%
# !pip install torch torchvision matplotlib numpy scikit-learn -q

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
np.random.seed(42); torch.manual_seed(42)
MAIN_BLUE='#1A3A6E'; IDA_RED='#CD0000'; FOREST='#2E7D32'; CRIMSON='#DC3545'
print('Ready: NN_DL_ch08_GNNViz')

# %% [markdown]
# ## Graph Construction

# %%
# TODO: Build interbank network graph

# %% [markdown]
# ## Model

# %%
# TODO: GCN/GAT implementation

# %% [markdown]
# ## Results

# %%
# TODO: Train, evaluate, visualize
